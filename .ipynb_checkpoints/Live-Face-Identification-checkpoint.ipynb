# %% [markdown]
# ### Imports and Constants

# %%
import numpy as np
import cv2
import os
from PIL import Image
import pickle
import pyautogui

VIDEONAME = "LiveFaceRecognition.mp4"
FRAMES_PER_SECOND = 24.0
RESOLUTION = "720p"

# %% [markdown]
# ### Video Settings

# %%
def change_res(cap, width, height):
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, width)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, height)

# dictionary of the standard dimensions for the resolution
STANDARD_DIMENSIONS = {
    "480p": (640, 480),
    "720p": (1280, 720)
}

def get_dims(cap, res):
    width, height = STANDARD_DIMENSIONS["480p"]
    if res in STANDARD_DIMENSIONS:
        width, height = STANDARD_DIMENSIONS[res]
    change_res(cap, width, height)
    
    return width, height

# dictoniary of the videotypes
VIDEO_TYPE = {
    "avi": cv2.VideoWriter_fourcc(*'XVID'),
    "mp4": cv2.VideoWriter_fourcc(*'XVID')
}

def get_video_type(filename):
    filename, ext = os.path.splitext(filename)
    if ext in VIDEO_TYPE:
        return VIDEO_TYPE[ext]
    return VIDEO_TYPE["mp4"]

# %% [markdown]
# ### Mouse Movement Function

# %%
def MoveMouse(XPos, YPos):
    
    xPos = XPos
    
    TopBarDelayPx = 31 # that bar with the name of the program at the top
    yPos = YPos + TopBarDelayPx
    
    pyautogui.moveTo(XPos, YPos)

# %% [markdown]
# ## The Actual Logic

# %%
face_cascade = cv2.CascadeClassifier('data/cascades/haarcascade_frontalface_alt2.xml')
recognizer = cv2.face.LBPHFaceRecognizer_create()
recognizer.read("trainer.yml")

with open("labels.pickle", "rb") as f:
    original_labels = pickle.load(f)
    labels = {v: k for k, v in original_labels.items()}
cap = cv2.VideoCapture(0)



# Changes video resolution
dims = get_dims(cap, RESOLUTION)

while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    # need gray to make face_cascade work
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor = 1.5, minNeighbors = 5)
    
    # face recognizer
    for (x, y, w, h) in faces:
        
        # region of interest: the part which shows your face
        roi_gray = gray[y: y+h, x: x+w]
        roi_color = frame[y: y+h, x: x+w]
        
        # saves the img
        gray_img_item = "my-gray-image.png"
        colored_img_item = "my-colored-image.png"
        cv2.imwrite(gray_img_item, roi_gray)
        cv2.imwrite(colored_img_item, roi_color)
                    
        # Draws box if face is seen
        blue_color = (0, 255, 0) # BGR scale
        stroke = 2
        end_cord_x = x + w
        end_cord_y = y + h
        cv2.rectangle(frame, (x, y), (end_cord_x, end_cord_y), blue_color, stroke)        
        
        # Moves mouse to the face position         
        MousePosX = x + w/2
        MousePosY = y + h/2
        MoveMouse(MousePosX, MousePosY)
    
    if ret == True:
        
        # Display the resulting frame
        cv2.imshow('frame',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
        
# When everything done, release everything
cap.release()
cv2.destroyAllWindows()
# Out:
# jackie-chan + conf level:  88.08586887819288
# jackie-chan + conf level:  86.34544637870417
# jackie-chan + conf level:  89.59983286062848
# jackie-chan + conf level:  88.38154743364339
# abraham-lincoln + conf level:  88.96539024069985
# abraham-lincoln + conf level:  89.64661149251324
# jackie-chan + conf level:  91.74691792517383
# jackie-chan + conf level:  170.61512294466257
# jackie-chan + conf level:  180.97208949868596
# ed-sheeran + conf level:  178.75735078255283
# jackie-chan + conf level:  182.05720004456754
# ed-sheeran + conf level:  181.21192913601652
# jackie-chan + conf level:  89.03935100333247
# jackie-chan + conf level:  83.95124853870696
# abraham-lincoln + conf level:  77.5623924242947
# abraham-lincoln + conf level:  75.92585533643694
# abraham-lincoln + conf level:  76.774645278257
# abraham-lincoln + conf level:  139.40072308577004
# jackie-chan + conf level:  167.05342539485335
# abraham-lincoln + conf level:  129.57543326971287
# ed-sheeran + conf level:  178.13291913160262
# abraham-lincoln + conf level:  132.69768786106144
# ed-sheeran + conf level:  177.4702003062186
# hanwe + conf level:  172.89572826481785
# ed-sheeran + conf level:  156.84091925513425
# jackie-chan + conf level:  179.41960995588846
# jackie-chan + conf level:  161.65477661074854
# jackie-chan + conf level:  150.79535210932562
# hanwe + conf level:  173.05379885738736
# jackie-chan + conf level:  152.148085014924
# hanwe + conf level:  174.59491763736764
# jackie-chan + conf level:  147.02602313516473
# ed-sheeran + conf level:  174.0960227128989
# ed-sheeran + conf level:  154.26363367149003
# hanwe + conf level:  174.76811607749943
# ed-sheeran + conf level:  151.5312941352302
# hanwe + conf level:  172.04143337084952
# abraham-lincoln + conf level:  129.0084398286268
# jackie-chan + conf level:  155.865630649324
# ed-sheeran + conf level:  190.08924188163562
# jackie-chan + conf level:  167.26078124162467
# ed-sheeran + conf level:  166.9387177770364
# bill-gates + conf level:  149.7004361955156
# jackie-chan + conf level:  142.72050341379355
# ed-sheeran + conf level:  162.7826825818742
# ed-sheeran + conf level:  164.8496029715322
# jackie-chan + conf level:  164.1334960332931
# jackie-chan + conf level:  166.02793413880187
# jackie-chan + conf level:  144.26436616799015
# hanwe + conf level:  168.8074045284718
# hanwe + conf level:  170.65587599192514
# jackie-chan + conf level:  162.89185975684407
# jackie-chan + conf level:  140.08917590844763
# ed-sheeran + conf level:  157.73508952075034
# jackie-chan + conf level:  158.60516554234408
# ed-sheeran + conf level:  200.37430057562077
# ed-sheeran + conf level:  203.56996869375794
# jackie-chan + conf level:  170.42844143177584
# ed-sheeran + conf level:  167.2477082220003
# jackie-chan + conf level:  155.2196647193488
# jackie-chan + conf level:  156.3519646048791
# ed-sheeran + conf level:  151.6999120501357
# jackie-chan + conf level:  145.61904622077572
# jackie-chan + conf level:  148.18086804394326
# ed-sheeran + conf level:  131.54672264808605
# jackie-chan + conf level:  142.11844924989768
# jackie-chan + conf level:  128.1426542433333
# jackie-chan + conf level:  118.996895519778
# jackie-chan + conf level:  141.3887421378392
# ed-sheeran + conf level:  121.09605767196052
# bill-gates + conf level:  134.14555740166224
# jackie-chan + conf level:  116.63100205139934
# jackie-chan + conf level:  109.71419117674449
# jackie-chan + conf level:  126.74146015585278
# ed-sheeran + conf level:  134.7612207692824
# bill-gates + conf level:  100.68783887849884
# jackie-chan + conf level:  134.43672633299926
# jackie-chan + conf level:  106.70862472289359
# jackie-chan + conf level:  138.10486818927203
# jackie-chan + conf level:  105.92216406909982
# jackie-chan + conf level:  144.32638208618565
# jackie-chan + conf level:  109.05056135121934
# jackie-chan + conf level:  144.14539207196748
# jackie-chan + conf level:  121.9620655042093
# jackie-chan + conf level:  110.6825363524951
# jackie-chan + conf level:  112.06654860564244
# jackie-chan + conf level:  143.77976708636066
# bill-gates + conf level:  107.55901479976474
# ed-sheeran + conf level:  140.90232991440004
# jackie-chan + conf level:  113.69488446314556
# ed-sheeran + conf level:  143.4059845079805
# ed-sheeran + conf level:  115.26060251945532
# jackie-chan + conf level:  114.94592923830491
# ed-sheeran + conf level:  146.5627192697083
# bill-gates + conf level:  113.40364338349724
# ed-sheeran + conf level:  144.08499450473064
# jackie-chan + conf level:  114.2627283983335
# jackie-chan + conf level:  111.58557162371768
# bill-gates + conf level:  107.59152411018832
# ed-sheeran + conf level:  141.00018086781927
# ed-sheeran + conf level:  111.45463000378359
# jackie-chan + conf level:  109.06615107241561
# bill-gates + conf level:  105.21988998504726
# ed-sheeran + conf level:  109.47097341764433
# jackie-chan + conf level:  144.56220047409082
# ed-sheeran + conf level:  110.51028487638946
# bill-gates + conf level:  106.37234338816309
# ed-sheeran + conf level:  143.85650120361905
# jackie-chan + conf level:  105.75240260873419
# ed-sheeran + conf level:  107.6790523419158
# jackie-chan + conf level:  105.56003043529377
# bill-gates + conf level:  106.96384970733887
# ed-sheeran + conf level:  141.94880551013534
# ed-sheeran + conf level:  107.62516664608471
# ed-sheeran + conf level:  144.87164357405823
# jackie-chan + conf level:  112.4401417377964
# jackie-chan + conf level:  107.88924433514009
# ed-sheeran + conf level:  115.015177303799
# jackie-chan + conf level:  143.15409263050879
# jackie-chan + conf level:  111.72864956919497
# ed-sheeran + conf level:  104.45840345483964
# jackie-chan + conf level:  99.51607163399615
# ed-sheeran + conf level:  142.53186035814116
# jackie-chan + conf level:  105.00622915140663
# ed-sheeran + conf level:  105.57750309436447
# jackie-chan + conf level:  101.5020928239575
# ed-sheeran + conf level:  138.4019657343471
# jackie-chan + conf level:  105.92465985377603
# ed-sheeran + conf level:  104.7430808580559
# jackie-chan + conf level:  105.3508625702684
# ed-sheeran + conf level:  142.09049324013185
# ed-sheeran + conf level:  103.20346578365617
# jackie-chan + conf level:  144.6149958659019
# jackie-chan + conf level:  108.46620314701289
# ed-sheeran + conf level:  102.99254145356765
# jackie-chan + conf level:  102.30899290566917
# jackie-chan + conf level:  138.12490239651527
# jackie-chan + conf level:  104.56755916324968
# bill-gates + conf level:  80.68191079503906
# bill-gates + conf level:  77.12962352312302
# bill-gates + conf level:  81.22899744367848
# abraham-lincoln + conf level:  83.85649688766513
# bill-gates + conf level:  78.3944835925123
# bill-gates + conf level:  77.77877736317424
# bill-gates + conf level:  90.41751964953566
# abraham-lincoln + conf level:  79.1744827522419
# jackie-chan + conf level:  84.14548845874943
# bill-gates + conf level:  79.44660078039084
# bill-gates + conf level:  78.31861050449643
# jackie-chan + conf level:  77.87519131324153
# abraham-lincoln + conf level:  77.33052368018149
# abraham-lincoln + conf level:  76.99014164418979
# hanwe + conf level:  90.70966365549933
# bill-gates + conf level:  75.99601001624279
# jackie-chan + conf level:  75.44389914858209
# bill-gates + conf level:  80.54619005433675
# bill-gates + conf level:  78.4730524881805
# bill-gates + conf level:  78.35549340374216
# bill-gates + conf level:  78.39908258890658
# bill-gates + conf level:  78.08310551794136
# bill-gates + conf level:  77.32086626353737
# bill-gates + conf level:  77.4778267851485
# bill-gates + conf level:  79.00585262662679
# jackie-chan + conf level:  79.25051178094616
# bill-gates + conf level:  78.61308418780213
# bill-gates + conf level:  79.21256706714327
# jackie-chan + conf level:  77.40266359706233
# bill-gates + conf level:  78.00887542869162
# jackie-chan + conf level:  77.84286854034293
# jackie-chan + conf level:  77.75617555177436
# jackie-chan + conf level:  80.44533521038238
# bill-gates + conf level:  77.54420984856483
# bill-gates + conf level:  76.72044030221144
# bill-gates + conf level:  78.19808064807289
# jackie-chan + conf level:  78.94496530542388
# bill-gates + conf level:  78.05275076216907
# bill-gates + conf level:  76.65682289104262
# abraham-lincoln + conf level:  77.06306237851699
# abraham-lincoln + conf level:  76.88581693872163
# bill-gates + conf level:  98.06164039307252
# bill-gates + conf level:  77.85330604971739
# bill-gates + conf level:  78.6025407206252
# bill-gates + conf level:  76.90450780412093
# bill-gates + conf level:  76.4526448776839
# bill-gates + conf level:  76.82056647768623
# bill-gates + conf level:  77.08639913827456
# bill-gates + conf level:  75.75714823216774
# bill-gates + conf level:  75.45542559840464
# bill-gates + conf level:  75.90855273650064
# bill-gates + conf level:  75.81342407996172
# bill-gates + conf level:  75.25212242437507
# bill-gates + conf level:  74.69762173864284
# bill-gates + conf level:  75.76700173524873
# bill-gates + conf level:  75.53772931909799
# hanwe + conf level:  76.5903010522767
# hanwe + conf level:  74.07939046766006
# abraham-lincoln + conf level:  75.66518806547546
# hanwe + conf level:  76.69092011439635
# bill-gates + conf level:  80.5749890132155
# bill-gates + conf level:  78.03955837758456
# bill-gates + conf level:  77.07869659732906
# bill-gates + conf level:  69.78686540406919
# abraham-lincoln + conf level:  78.99769889941241
# abraham-lincoln + conf level:  81.5336703795058
# hanwe + conf level:  80.55622991633372
# abraham-lincoln + conf level:  80.45163985299851
# hanwe + conf level:  83.0888885004403
# hanwe + conf level:  81.09289033492196
# abraham-lincoln + conf level:  78.04737638443117
# abraham-lincoln + conf level:  78.01992558893795
# abraham-lincoln + conf level:  79.90740097605122
# bill-gates + conf level:  79.87076696161836
# abraham-lincoln + conf level:  80.36475066758162
# abraham-lincoln + conf level:  80.85755789229682
# abraham-lincoln + conf level:  80.02795118147763
# abraham-lincoln + conf level:  80.22308040089119
# hanwe + conf level:  80.09906936232875
# hanwe + conf level:  80.80310653225796
# hanwe + conf level:  80.60244433571525
# abraham-lincoln + conf level:  81.78411564508933
# abraham-lincoln + conf level:  80.55074638371562
# abraham-lincoln + conf level:  80.12485776906998
# abraham-lincoln + conf level:  79.31849448152805
# abraham-lincoln + conf level:  80.01272002020964
# abraham-lincoln + conf level:  79.22997496788356
# abraham-lincoln + conf level:  82.92408156009589
# abraham-lincoln + conf level:  80.80802371747133
# jackie-chan + conf level:  85.66400464941688
# jackie-chan + conf level:  75.12164351265525
# jackie-chan + conf level:  75.1558583720703
# jackie-chan + conf level:  76.82665130288409
# abraham-lincoln + conf level:  71.56413096087873
# abraham-lincoln + conf level:  72.84017738176784
# bill-gates + conf level:  71.95745782546953
# bill-gates + conf level:  71.63579531526727
# abraham-lincoln + conf level:  70.8782052607147
# abraham-lincoln + conf level:  83.67327925749507
# jackie-chan + conf level:  80.35107348292522
# jackie-chan + conf level:  81.57296639461242
# abraham-lincoln + conf level:  82.93414238502349
# abraham-lincoln + conf level:  79.87896405494814
# abraham-lincoln + conf level:  81.08744560768493
# jackie-chan + conf level:  81.27755917976725
# jackie-chan + conf level:  80.58442532041325
# jackie-chan + conf level:  83.29754757089869
# jackie-chan + conf level:  81.27219943341626
# jackie-chan + conf level:  77.67264875244837
# jackie-chan + conf level:  79.09420967107415
# jackie-chan + conf level:  76.69288865065066
# jackie-chan + conf level:  78.73485268645099
# jackie-chan + conf level:  83.53601640721438
# jackie-chan + conf level:  80.05087816585194
# jackie-chan + conf level:  80.48671920157739
# jackie-chan + conf level:  80.99927510891821
# jackie-chan + conf level:  81.57926374121595
# jackie-chan + conf level:  82.49242723710672
# jackie-chan + conf level:  83.77310556607658
# jackie-chan + conf level:  81.23233202320834
# jackie-chan + conf level:  78.40789226677232
# jackie-chan + conf level:  77.48047621216683
# jackie-chan + conf level:  76.63762882069717
# jackie-chan + conf level:  81.13417400373628
# jackie-chan + conf level:  79.99076678245906
# jackie-chan + conf level:  79.8750755440523
# jackie-chan + conf level:  81.80584162068834
# jackie-chan + conf level:  80.94890218908033
# jackie-chan + conf level:  78.93299373763496
# jackie-chan + conf level:  80.36925412444974
# jackie-chan + conf level:  80.48990266471733
# jackie-chan + conf level:  79.6452684316482
# jackie-chan + conf level:  77.21569695207441
# jackie-chan + conf level:  79.27608486508157
# hanwe + conf level:  81.45396895462117
# jackie-chan + conf level:  80.00674511689411
# jackie-chan + conf level:  80.73912350880825
# jackie-chan + conf level:  80.34119812057509
# jackie-chan + conf level:  77.06221659310525
# jackie-chan + conf level:  77.7629119102314
# jackie-chan + conf level:  76.49973833337872
# jackie-chan + conf level:  79.75909693669522
# jackie-chan + conf level:  81.74041305649749
# jackie-chan + conf level:  82.22175062420838
# jackie-chan + conf level:  81.19831891669854
# jackie-chan + conf level:  81.11571442418838
# jackie-chan + conf level:  81.86973558093302
# jackie-chan + conf level:  79.29457004458483
# jackie-chan + conf level:  78.89585750641633
# jackie-chan + conf level:  78.75144855494925
# jackie-chan + conf level:  85.9151853304372
# jackie-chan + conf level:  84.87415778981263
# jackie-chan + conf level:  81.11914278731997
# jackie-chan + conf level:  82.71120053616406
# jackie-chan + conf level:  79.40476980112709
# hanwe + conf level:  84.37151304672663
# bill-gates + conf level:  84.04319369938185
# hanwe + conf level:  84.23560890743119
# jackie-chan + conf level:  81.83824323903681
# jackie-chan + conf level:  81.23315718253681
# hanwe + conf level:  86.22360516616111
# jackie-chan + conf level:  81.53450609058751
# jackie-chan + conf level:  83.65479679861468

# %% [markdown]
# # Train Faces

# %%
BASE_DIR = os.path.dirname(os.path.abspath(""))
image_dir = os.path.join(BASE_DIR, "live_face_recognition\data\images")

face_cascade = cv2.CascadeClassifier('data/cascades/haarcascade_frontalface_alt2.xml')
recognizer = cv2.face.LBPHFaceRecognizer_create()

current_id = 0
label_ids = {}
y_labels = []
x_train = []

for root, dirs, files in os.walk(image_dir):
    for file in files:
        if file.endswith("png") or file.endswith("jpg") or file.endswith("jpeg"):
            path = os.path.join(root, file)
            label = os.path.basename(os.path.dirname(path)).lower()
            
            if not label in label_ids:
                label_ids[label] = current_id
                current_id += 1
            id_ = label_ids[label]
            
            pil_image = Image.open(path).convert("L") # greyscales the img
            image_array = np.array(pil_image, "uint8")
            faces = face_cascade.detectMultiScale(image_array, scaleFactor = 1.5, minNeighbors = 5)
            
            for (x, y, w, h) in faces:
                roi = image_array[y: y+h, x: x+w]
                x_train.append(roi)
                y_labels.append(id_)

with open("labels.pickle", "wb") as f:
    pickle.dump(label_ids, f)
    
recognizer.train(x_train, np.array(y_labels))
recognizer.save("trainer.yml")
